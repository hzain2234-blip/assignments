# %%
# Personal Information
name = "Zain"
age = 18
height = 5.8
is_student = True
favorite_subject = "Computer Science"
favorite_number = 7
percentage = 85.5
city = "Karachi"

# Display Personal Profile
print("====================================")
print("       MY PERSONAL PROFILE")
print("====================================")

print("Zain:", name)
print("Age:", age)
print("Height:", height)
print("Student:", is_student)
print("Favorite Subject:", favorite_subject)
print("Favorite Number:", favorite_number)
print("Percentage:", percentage)
print("City:", city)

print("====================================")
print("Welcome to my personal profile!")
print("====================================")
# Out:
# ====================================
#        MY PERSONAL PROFILE
# ====================================
# Name: Your Name
# Age: 18
# Height: 5.8
# Student: True
# Favorite Subject: Computer Science
# Favorite Number: 7
# Percentage: 85.5
# City: Karachi
# ====================================
# Welcome to my personal profile!
# ====================================
