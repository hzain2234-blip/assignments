# %%
#Task 1 — Store Information

store_name = input("Enter the name: ")

manager_name = input("enter the manager name: ")

store_code = input("Enter the store code: ")


category_code = store_code[0:4]
year = store_code[5:9]
city_code = store_code[10:13]

#Task 2 — Create the Inventory

products = ["Laptop", "Mouse", "Keyboard", "Monitor", "Headphones"]

total_product = len(products)

#Task 3 — Add New Products

new_product = input("Enter the new product: ")

products.append(new_product)

products.extend(["Webcam", "USB Hub", "Speaker"])

#Task 4 — Insert a Product

monitor_position = products.index("Monitor")

products.insert(monitor_position + 1, "Printer")

#Task 5 — Remove a Discontinued Product

products.remove("Headphones")

# Task 6 — Process a Recent Shipment

shipment = ["Tablet", "Smart Watch", "Power Bank"]

products.extend(shipment)

removed_product = products.pop()

# Task 7 — Product Information

laptop_position = products.index("Laptop")
mouse_count = products.count("Mouse")

# Task 8 — Sort the Inventory

products.sort()
sorted_inventory_az = products.copy()

products.sort(reverse=True)
sorted_inventory_za = products.copy()

#Task 9 — Reverse the Inventory

products.reverse()
reversed_inventory = products.copy()

#Task 10 — Create an Inventory Backup

backup_products = products.copy()

# Task 11 — Clear Temporary Inventory

temporary_inventory = ["Test Laptop", "Test Mouse", "Test Keyboard"]

temporary_inventory.clear()

#Task 12 — Final Challenge: Featured Products

featured_products = products[1:4]
# Out:
# Enter the name: Imtiaz
# enter the manager name: Zain
# Enter the store code: ELEC-2026-KHI
# Enter the new product: Charger
